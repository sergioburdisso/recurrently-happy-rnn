# %% [markdown]
# # Having Fun with Recurrent Neural Networks (RNN)

# %% [markdown]
# **~$ whoami**

# %% [markdown]
# Sergio G. Burdisso (sergio.burdisso@gmail.com)

# %% [markdown]
# **~$ cat recommended_reading.txt**

# %% [markdown]
# [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)

# %% [markdown]
# ## 1. Imports

# %%
import tensorflow as tf
import numpy as np

from tensorflow.contrib import layers
from tensorflow.contrib import rnn

from idataset import Dataset

# %% [markdown]
# ## 2. Hyper-parameters

# %%
hStateSize = 512  # Number of Hidden Units (NHU)
maxSeqLength = 128  # MSL
nLayers = 3  # NL

learningRate = 1e-3  # 0.001
dropoutProb = 0.3

batchSize = 200  # BS
alphaSize = Dataset.get_alphabet_size()  # AS

# %% [markdown]
# ## 3. Our model
# ### 1. Inputs

# %%
def tf_create_inputs():
    global X_train, y_train, h_state_input, dropout, batch_size

    X_train = tf.placeholder(tf.uint8, [None, None], name="X_train")  # (BS, MSL)
    # expected outputs = same sequence shifted by 1 since we are trying to predict the next character
    y_train = tf.placeholder(tf.uint8, [None, None], name="y_train")  # (BS, MSL)
    h_state_input = tf.placeholder(tf.float32, [None, hStateSize * nLayers], name="h_state_input")  # (BS, NHU*NL)


    dropout = tf.placeholder(tf.float32, name="dropout")
    batch_size = tf.placeholder(tf.int32, name="batch_size")

# %% [markdown]
# ## 3. Our model
# ### 2. Architecture

# %%
def tf_create_architecture():
    global rnn_cells_stack_outdropout

    rnn_cells = [rnn.GRUCell(hStateSize) for _ in range(nLayers)]

    rnn_cells_indropout = [
        rnn.DropoutWrapper(cell, input_keep_prob=(1 - dropout))
        for cell in rnn_cells
    ]

    rnn_cells_stack = rnn.MultiRNNCell(rnn_cells_indropout, state_is_tuple=False)
    # dropout for the softmax layer

    rnn_cells_stack_outdropout = rnn.DropoutWrapper(
        rnn_cells_stack, output_keep_prob=(1 - dropout)
    )

# %% [markdown]
# ## 3. Our model
# ### 3. TF Graph  (1/3) - Forward Propagation

# %%
def tf_graph_forward_propagation():
    global h_state_outputs, next_h_state_input, X_train_oh, y_train_oh

    X_train_oh = tf.one_hot(X_train, alphaSize, 1.0, 0.0)  # (BS, MSL, AS)
    y_train_oh = tf.one_hot(y_train, alphaSize, 1.0, 0.0)  # (BS, MSL, AS)

    h_state_outputs, next_h_state_input = tf.nn.dynamic_rnn(
        rnn_cells_stack_outdropout,
        X_train_oh,
        dtype=tf.float32,
        initial_state=h_state_input
    )
    # h_state_outputs.shape = (BS, MSL, NHU)
    # next_h_state_input.shape = (BS, NHU*NL), this is the last state in the sequence


    next_h_state_input = tf.identity(next_h_state_input, name='next_h_state_input')  # just to give it a name

# %% [markdown]
# ## 3. Our model
# ### 3. TF Graph  (2/3) - Fully Connected Net + Softmax

# %%
def tf_graph_fullyconnected_softmax():
    global h_state_outputs_flat, y_preds, y_preds_prob
    # flatting
    h_state_outputs_flat = tf.reshape(h_state_outputs, [-1, hStateSize]) # (BS*MSL, NHU)

    y_preds = layers.fully_connected(  # (BS*MSL, AS)
        h_state_outputs_flat,
        alphaSize,
        activation_fn=tf.nn.relu # the default
        # activation_fn=tf.nn.softmax => WARNING: This op expects unscaled logits, since it performs a softmax on logits internally for efficiency. Do not call this op with the output of softmax, as it will produce incorrect results.
    )

    y_preds_prob = tf.nn.softmax(y_preds, name="y_preds_prob")  # (BS*MSL, AS)

# %% [markdown]
# ## 3. Our model
# ### 3. TF Graph  (3/3) -  Training

# %%
def tf_graph_training():
    global y_train_oh_flat, loss, train_step
    # flatting
    y_train_oh_flat = tf.reshape(y_train_oh, [-1, alphaSize])  # (BS*MSL, AS)

    loss = tf.nn.softmax_cross_entropy_with_logits(logits=y_preds, labels=y_train_oh_flat)  # (BS*MSL)
    loss = tf.reshape(loss, [batch_size, -1])  # (BS, MSL)

    train_step = tf.train.AdamOptimizer(learningRate).minimize(loss)

# %% [markdown]
# ## 4. Training (1/2)

# %%
def tf_init_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True # only needed when using GPU
    sess = tf.Session(config=config)
    sess.run(tf.global_variables_initializer())
    return sess

# %% [markdown]
# ## 4. Training (2/2)

# %%
def train(pattern_path, trained_model_name, n_epochs=20):
    from time import time

    dataset = Dataset.load_from_files(pattern_path)
    sess = tf_init_session()
    n_chars_processed = 0
    oepoch = -1
    t_start = time()

    # initial input hidden state (zero)
    in_h_state = np.zeros([batchSize, hStateSize * nLayers])
    try:        
        print("[training] starting to learn :) ...")
        for epoch, X_train_batch, y_train_batch in Dataset.get_training_batches(
            n_epochs, batchSize, maxSeqLength, dataset
        ):

            _, next_in_h_state = sess.run(
                [train_step, next_h_state_input],
                feed_dict={
                    X_train: X_train_batch, y_train: y_train_batch, h_state_input: in_h_state,
                    dropout: dropoutProb, batch_size: batchSize
                }
            )
            in_h_state = next_in_h_state

            n_chars_processed += batchSize * maxSeqLength
            if oepoch != epoch:
                oepoch = epoch
                print(
                    "[training][epoch %d/%d] characters processed: %d" %
                    (epoch + 1, n_epochs, n_chars_processed)
                )
    except KeyboardInterrupt:
        pass

    print("[training] training finished (%.1f mins)" % ((time() - t_start) / 60))
    saved_file = tf.train.Saver().save(sess, 'trained_models/test/%s' % trained_model_name)
    print("[training] model saved: " + saved_file)

# %% [markdown]
# ## 4. Sequence Generator

# %%
def generate_seq(model_path, seq_start="a", length=1000):
    tf.reset_default_graph()

    output_seq = seq_start    
    sess = tf_init_session()
    with sess:
        try:
            saver = tf.train.import_meta_graph(model_path + '.meta')
        except OSError:
            print("[generate_seq] model %s does not exist" % model_path)
            return seq_start

        saver.restore(sess, model_path)

        in_X = Dataset.encode_str(output_seq)
        in_X = np.array([in_X])  # "1 bach of 1 sequence"

        in_h_state = np.zeros([1, hStateSize * nLayers], dtype=np.float32)  # [ BATCHSIZE, INTERNALSIZE * NLAYERS]
        for i in range(length):
            y_preds_prob, next_in_h_state = sess.run(
                ['y_preds_prob:0', 'next_h_state_input:0'],
                feed_dict={
                    'X_train:0': in_X,
                    'h_state_input:0': in_h_state,
                    'dropout:0': 0., 'batch_size:0': 1
                }
            )
            in_h_state = next_in_h_state

            char = Dataset.peek_char_from_prob(y_preds_prob[-1], top_n=2)
            in_X = np.array([[char]])  # "1 bacth of 1 sequence of 1 char"

            output_seq += Dataset.decode_char(char)
        return output_seq

# %% [markdown]
# ## 5. Gluing it all together

# %%
# This function will give life to our RNN
def tf_work_your_magic():
    tf.reset_default_graph() # we're gonna make magic more than once! XD

    tf_create_inputs()
    tf_create_architecture()
    tf_graph_forward_propagation()
    tf_graph_fullyconnected_softmax()
    tf_graph_training()

# %% [markdown]
# ## Let the fun begin...

# %% [markdown]
# * Learning to "payar" (going The Martin Fierro's way).
# * Learning to compose some music.
# ![](./images/pereyra_mate.jpg)

# %% [markdown]
# ## 1. Let's learn how to _payar_!

# %% [markdown]
# ![](./images/pereyra_guitar.jpg)

# %% [markdown]
# Aquí me pongo a cantar<br>
# al compás de la vigüela,<br>
# que el hombre que lo desvela<br>
# una pena estrordinaria,<br>
# como la ave solitaria<br>
# con el cantar se consuela.<br>
# <br>
# Pido a los santos del cielo<br>
# que ayuden mi pensamiento:<br>
# ...

# %% [markdown]
# ## 1. Let's learn how to _payar_!
# ### 1.1. First things  first - preprocessing
#
# [dataset/martinfierro](dataset/martinfierro/)

# %%
mfierro_path = "dataset/martinfierro/"
mfierro_files = mfierro_path + "*.txt"

# NOTE: We need to run this code below only once
Dataset.encode_files(mfierro_files, target_codec="utf8")
Dataset.normalize_files(mfierro_files)
# Out:
# [dataset] encoding file 'dataset/martinfierro/martinfierro.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/martinfierro/martinfierrovuelta.txt' from utf8 to utf8.
# [dataset] normalizing file 'dataset/martinfierro/martinfierro.txt'.
# [dataset] normalizing file 'dataset/martinfierro/martinfierrovuelta.txt'.

# %% [markdown]
# [dataset/martinfierro](dataset/martinfierro/)

# %% [markdown]
# ## 1. Let's learn how to _payar_!
# ### 1.2. Training

# %%
# making sure our RNN is alive
tf_work_your_magic()


train(mfierro_files, input("model name: "), n_epochs=10)

# NOTE: if it's taking too long, just press:
#       <Esc> and then <I> twice to interrupt
#       the process and save the model
# Out:
# model name: pepe10
# [dataset] file 'dataset/martinfierro/martinfierro.txt' loaded.
# [dataset] file 'dataset/martinfierro/martinfierrovuelta.txt' loaded.
# [dataset] finished (208161 characters loaded).
# [training] starting to learn :) ...
# [training][epoch 1/10] characters processed: 25600
# [training][epoch 2/10] characters processed: 230400
# [training][epoch 3/10] characters processed: 435200
# [training][epoch 4/10] characters processed: 640000
# [training][epoch 5/10] characters processed: 844800
# [training][epoch 6/10] characters processed: 1049600
# [training][epoch 7/10] characters processed: 1254400
# [training][epoch 8/10] characters processed: 1459200
# [training][epoch 9/10] characters processed: 1664000
# [training][epoch 10/10] characters processed: 1868800
# [training] training finished (0.7 mins)
# [training] model saved: trained_models/test/pepe10

# %% [markdown]
# ## 1. Let's learn how to _payar_!
# ### 1.3. Payando :)

# %%
canto = generate_seq(
    model_path=input("Trained model path: "),
    seq_start=input("Sequence starts with: "),
    length=1000
)
print(canto)
# Out:
# Trained model path: trained_models/test/pepe10
# Sequence starts with: aqui
# INFO:tensorflow:Restoring parameters from trained_models/test/pepe10
# aquillrreero
# 4::yee  ea e ee e ee ae eerr
# 6::y e eee e eee  ee eeaaa
#
# 1: e  eee  e ee e  ae e earoa
#
# :  ee  aeaaa  e ae e a aaa
#
# :  ae  ea  ea  ea ea eaaa
#
# :: e  ee e ea  a e aaaaa
#
# :  eea  ea e e e eaaaa
#
# :: e e  e a  aa ea  aa aaaa
# 6: e  e ea  a  eaaaa eaaaa
#
# :: e ee ea e eea  ae e aeao
#
# :: ae  ee e a  a aaa e aara
#
# : y   ea  aa a e ea  ee aea
#
# 1: ee  a e e ee  a  aa a aeo
#
# 1: ee  a aa e  e ea e e ee eao
#
# :: a  ae e ae  a  aa ea aeo
#
# :  e  a e  ea e ea e aa aea
#
# :  a ea  a  e  a e  aa aaaa
#
# :: ae  eaa  ea  e eaa ae eaa
#
# :: a  e a e e  a  ea e a ara
#
# :  e  a aa  a  ea e ea eaa
#
# :  ee  e ea e e  a e aa aea
#
# :  ae e  aaa  a e eaa eea
#
# : ye eee e  a  a  e eaa aao
#
# :  a e e  a  aa  ea  ea aaa
#
# :  e  ea aa  eaa  a a aara
#
# 1: e e ea ea  a  aa  aa eeoa
#
# :: ee ee e e ae e eea ea aea
#
# :  e e e  e e  a  e ea e aeo
#
# :  a  ae e e e  eeaa  eaaa
#
# :  ee  eaaaa e  eea  eaaa
#
# :  a  aa ea  a  e e aa aeoa
# :: ee  a  e a  ee eea  eeao
#
# :  a  a ea  aa  ee  aaaa
#
# :: ee  a e ea  e  ee  ea eeoa
#
# 1: a  a e a e e

# %% [markdown]
# ## 1. Let's learn how to _payar_!
# ### 1.4. Pretrained Payadores :D

# %%
from re import sub as re_replace

trained_epochs = [0, 50, 400]

# %%
trained_model = "trained_models/martinfierro/%depochs" % trained_epochs[1]

canto = generate_seq(model_path=trained_model, seq_start=input("Starts with: "), length=1000)

canto = re_replace(r'\d:\s', '', canto) # deleting all :1,:2,:3... etc.
print(canto)
# Out:
# Starts with:
# INFO:tensorflow:Restoring parameters from trained_models/martinfierro/400epochs
#       manas
# el ciego y las carazos,
# y aqui no ma gan escura
# tengan tener el cantar.
#
# Yo no sey cantorecantor
# a mes de las que es sucor,
# yo no soy rentrando el como,y so es de tanta cantar:
# si po dejar e algun rancho
# se lo quise canta gartar.
#
# Yl se coltido a todito
# la gusta que lo se ponga,
# yo se que pas conoce al
# y conte hombre se mo el nen,
# pero poco entre el sueno
# farrigonos que hacia cruta.
#
# A su cargue ten peligro,
# parque le tienen se erieza:
# ya no hay quien no por venia,
# yo tiene que sobre estantes,
# porque el pobre se dintraba
# y su carguenta sin nadre.
#
# Es triste en ma sal de mismo,
# nunca le folta el peluero;
# yo si lo que hay sanide
# el hombre y el solo el pierto;
# y ya de el ser premenio
# lo medao que sabe diene.
#
# A vaces decia al vieje
# y esta la suerte no liera,
# hicieron ciliar la pierra
# con una cora certena.
# Aujuna, pobre tidia,
# no teme man que no sartida!
#
# Si se alla a una mujer
# q

# %% [markdown]
# ## 2. Let's learn how to compose music!
# ### ( Now we're talking :D )
# ![](./images/abc.png)

# %% [markdown]
# ### The ABC Notation (http://abcnotation.com/)
#
# Example:
# ```
# X: 1
# T: Cooley's
# M: 4/4
# L: 1/8
# R: reel
# K: Emin
# Q:120
# |:D2|EB{c}BA B2 EB|~B2 AB dBAG|FDAD BDAD|FDAD dAFD|
# EBBA B2 EB|B2 AB defg|afe^c dBAF|DEFD E2:|
# |:gf|eB B2 efge|eB B2 gedB|A2 FA DAFA|A2 FA defg|
# eB B2 eBgB|eB B2 defg|afe^c dBAF|DEFD E2:|
#
# ```

# %% [markdown]
# **Good tutorial:** [How to interpret abc music notation](http://www.lesession.co.uk/abc/abc_notation.htm)

# %% [markdown]
# ### Playing ABC files
#
#
# **Software:** http://abcnotation.com/software
#
# **Webplayer:** https://abcjs.net/abcjs-editor.html
#
#
# **But** we're  gonna be using these commands: [abcmidi](http://abc.sourceforge.net/abcMIDI/original/), [timidity](https://sfxpt.wordpress.com/2015/02/02/how-to-play-midi-files-under-ubuntu-linux/).
#
# **Installation:**
# ```
# ~$ sudo apt install abcmidi
# ~$ sudo apt-get install timidity timidity-interfaces-extra
# ```
# **Usage:**
# ```
# ~$ abc2midi song.abc -o song.mid
# ~$ timidity song.mid
# ```

# %% [markdown]
# ## 2. Let's learn how to compose music!
# ### 2.1. Remember, first things  first - preprocessing
#
# [dataset/music](dataset/music/)

# %%
music_path = "dataset/music/"
music_files = music_path + "**/*.[ta][xb][tc]"  # Recursively, all .abc or .txt files

# NOTE: We need to run this code below only once
Dataset.encode_files(music_files, target_codec="utf8")
Dataset.normalize_files(music_files)
# Out:
# [dataset] encoding file 'dataset/music/The Nottingham Collection/morris.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/playford.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/slip.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/reelsa-c.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/reelsu-z.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/xmas.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/reelsr-t.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/reelsh-l.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/hpps.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/jigs.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/coll.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/ashover.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/reelsd-g.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/The Nottingham Collection/waltzes.txt' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/infaco.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bilfal.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/yazonl.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/britox.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/davash.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/kamkar.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/pinwis.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/enyori.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/chipss.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/phiint.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/rambli.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/drunken.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/chrrem.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/alglet.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/godbless.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/eltsor.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ducktale.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/rigyou.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/iroina.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/syshyp.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/audsho.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/noddont.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/skrsca.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/weesay.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/rawhide.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ledimm.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/beemoo.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ericoc.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bluson.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/drabla.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/austin.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/noddon.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/tomfre.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/lynswe.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/dukes.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/blocal.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/disind.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/curboy.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/steedg.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bruhum.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/badwhe.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/dueling.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/chrvoyh.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/irishw.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/zelsarm.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/foolem.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/weegoo.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/evewak.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ff3terra.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bontot.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/mothom.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/caryou.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/blibar.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/silentn.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/johgod.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/blaund.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/yngsev.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/pincom.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/breif.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/acdhig.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bocgod.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/gooiris.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/curclo.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ghostsolo.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/typbla.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/zelclo.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/iroiro.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/silpro.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/eaghot.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bliall.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/subsante.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/beacal.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ff3tow.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/johimag.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/stycome.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/redscar.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ccgon.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/stieng.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/noflea.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/okares.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/yanlem.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bacprel.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/monalw.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/extmor.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/busgly.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/baccha.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/scorchd.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/xfiles.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/shafoo.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/nattor.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/acdhel.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/daunotm.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/funeral.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/leddyr.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/crewha.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/scosti.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/tnginne.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/colspe.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/curlul.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bringmem.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/metout.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/albtak.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/coneyd.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/guenos.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/mat3am.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/bosmore.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/madpapd.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/blisterd.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/glocon.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/ledbat.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/missing.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/eltdont.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1/zelund9.abc' from utf8 to utf8.
# [dataset] encoding file 'dataset/music/lotro1
abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f245.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ah.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/bc.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f10.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f302.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f172.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f154.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f316.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f259.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f99.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f236.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f271.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f213.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/do.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g9.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f19.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f206.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f332.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f75.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f262.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f61.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f204.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f72.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f6.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/rrg.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f51.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f54.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f313.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f63.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f272.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/bd.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ai.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f195.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f323.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f82.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ra.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f46.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f184.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f117.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f110.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g10.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/fc.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f57.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f44.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f77.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f208.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f348.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f123.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f52.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f81.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f178.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f155.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f304.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g7.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f250.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f190.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f69.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f62.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f21.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f103.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f18.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f227.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f40.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g5.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/re.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ab.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f5.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f223.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g6.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f257.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f217.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f249.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f148.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f295.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f308.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f42.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f80.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f45.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f300.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f37.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f60.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f126.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g11.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f20.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f306.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f344.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/jd.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f292.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f212.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f67.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f76.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/je.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f158.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f97.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f107.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f326.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f183.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f58.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f241.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/am.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f119.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f156.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f13.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/n8.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f353.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f84.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ar.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f14.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f317.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f91.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f64.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f56.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f269.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f261.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/dq.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f141.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f290.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f333.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/rh.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f244.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/jf.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f276.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f248.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f22.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f247.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f320.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f197.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f116.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f321.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f243.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f92.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g2.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f193.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f349.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f181.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f109.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ba.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f232.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ji.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f192.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f127.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ad.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f36.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f24.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f345.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/rb.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f33.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f90.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f170.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f83.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f199.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/g12.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f140.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/n2.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/au.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f48.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f26.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f312.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/n1.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f66.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/dn.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/n11.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f133.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f284.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f174.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f89.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f175.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f200.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/n3.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/rf.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f310.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f354.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/d.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f327.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/dr.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f124.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f289.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/af.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f71.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f330.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f28.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f53.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f273.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f357.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f189.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/aq.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ag.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f78.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f2.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f79.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f96.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f341.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f32.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f7.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f49.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/ak.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f136.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f299.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f325.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/dh.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f352.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f258.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f226.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f169.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f267.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f336.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f111.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f205.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f254.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f87.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f153.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f17.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f166.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/aa.abc'.
# [dataset] normalizing file 'dataset/music/lotro0/f343.abc'.

# %% [markdown]
# ## 1. Let's learn how to compose music!
# ### 2.2. Training

# %%
# making sure our RNN is alive
tf_work_your_magic()

train(music_files, input("model name: "), n_epochs=1)

# Warning: this dataset is 12,703,923 chars long...
#          so each epoch is going to take a while.

# NOTE1: if it's taking too long, just press:
#       <Esc> and then <I> twice to interrupt
#       the process and save the model

# %% [markdown]
# ## 2. Let's dance!
# ### 2.3. Dancing like a robot (a tiny little baby robot) :D
#
# But first, we need a DJ:

# %%
def play(str_abc):
    from os import system
    tmp_song = "_tmp_song.abc"
    with open(tmp_song, "w") as abc_song:
        abc_song.write(str_abc)

    system('bash play_abc.bash ' + tmp_song)

# %% [markdown]
# ## 2. Let's dance!
# ### 2.3. Dancing like a robot (a tiny little baby robot) :D

# %%
song = generate_seq(
    model_path=input("Trained model path: "),
    seq_start=input("Sequence starts with: "),
    length=1000
)
print(song)

play(song)
# NOTE: press <Esc> and then <I> twice to stop playing

# %% [markdown]
# ## 2. Let's dance!
# ### 2.3. Dancing like a Pretrained Robot XD

# %%
from re import sub as re_replace

trained_epochs = [0, 1, 4, 8]

# %%
trained_model = "trained_models/music/%depochs" % trained_epochs[-1]

song = generate_seq(model_path=trained_model, seq_start="X:", length=1500)

